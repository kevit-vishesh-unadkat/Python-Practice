# %%
class Person:

    def __init__(self,name_input,country_input):
        self.name=name_input
        self.country=country_input

    def greet(self):
        if self.country=="India":
            print('Namste',self.name)

        else:
            print("Hello",self.name)

# %%
p=Person("vishesh","india")
print(p)
print(p.name)
print(p.country)
Person("Nirmit","US")    
# IN CONCLUSION p is not a object p is refrence witch
# Out:
# ...
# vishesh
# india

# %%
# what if i try to access non-existance attribute
p.gender
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 # what if i try to access non-existance attribute
# ----> 2 p.gender
#
# AttributeError: 'Person' object has no attribute 'gender'

# %%
# Attribute creation from outside the class
p.gender='male'

# class ke bahar se class ke under ek attribute create kar diya

p.gender
# Out:
# 'male'

# %% [markdown]
# Referrnce Variables

# %%
class Person:

    def __init__(self):
        self.name='vishesh'
        self.gender='male'

Person()
p=Person() 
# p me refernce store kar rahe hai Person class ka 
# p contains the addrees of an object 
# p itself is not a objcet

q=p 
print(id(q))
print(id(p))
# Out:
# 133445910844256
# 133445910844256

# %%
print(p.name)
print(q.name)
q.name='nirmit'
print(p.name)
print(q.name)
# Out:
# vishesh
# vishesh
# nirmit
# nirmit

# %% [markdown]
# Pass By Refernce

# %%
class Person:
    def __init__(self,name,gender):
        self.name=name
        self.gender=gender

# outside the class
def greet(person):
    print('Hi my name is ',person.name,'and i am ',person.gender)
    p1=Person('nirmit','male')
    return p1

p=Person('vishesh','male')
x=greet(p)
print(x.name)
print(x.gender)

# function ko ek object as input diya
# in python we can ek class ka object as input to the function
# and also ek function ek object ne return kari sake che
# Out:
# Hi my name is  vishesh and i am  male
# nirmit
# male

# %%
class Person:
    def __init__(self,name,gender):
        self.name=name
        self.gender=gender

# outside the class
def greet(person):
    print(id(person))
    print('Hi my name is ',person.name,'and i am ',person.gender)
    

p=Person('vishesh','male')
print(id(p))
greet(p)
# Out:
# 133445647943856
# 133445647943856
# Hi my name is  vishesh and i am  male

# %%
class Person:
    def __init__(self,name,gender):
        self.name=name
        self.gender=gender

# outside the class
def greet(person):
    print(id(person))
    person.name='yug'
    print(person.name)
    

p=Person('vishesh','male')
print(id(p))
greet(p)
print(p.name)
# Out:
# 133445910813936
# 133445910813936
# yug
# yug

# %%
class Person:
    def __init__(self,name,gender):
        self.name=name
        self.gender=gender

# outside the class
def greet(person):
    person.name='yug'
    return person
    

p=Person('vishesh','male')
print(id(p))
p1=greet(p)
print(id(p1))


# address koi no sake bcz te object ni mutability uper depend kare che 
# jo object mutable hase to same rese
# ane jo address immutable hase to different address malse
# but in python objects are mutable
# Out:
# 133445648129312
# 133445648129312

# %% [markdown]
# instance variable

# %%
class Person:

    def __init__(self,name,country):
        self.name=name
        self.country=country

Person("vishesh","India")
Person("yug","USA")

# instance variable ek aisa variable jiska value alag alag objects ke liye alag alag haota hai

# %%
class Atm:

  # constructor(special function)->superpower -> 
  def __init__(self):
    print(id(self))
    self.pin = ''
    self.__balance = 0
    #self.menu()

  def get_balance(self):
    return self.__balance

  def set_balance(self,new_value):
    if type(new_value) == int:
      self.__balance = new_value
    else:
      print('beta bahot maarenge')

  def __menu(self):
    user_input = input("""
    Hi how can I help you?
    1. Press 1 to create pin
    2. Press 2 to change pin
    3. Press 3 to check balance
    4. Press 4 to withdraw
    5. Anything else to exit
    """)

    if user_input == '1':
      self.create_pin()
    elif user_input == '2':
      self.change_pin()
    elif user_input == '3':
      self.check_balance()
    elif user_input == '4':
      self.withdraw()
    else:
      exit()

  def create_pin(self):
    user_pin = input('enter your pin')
    self.pin = user_pin

    user_balance = int(input('enter balance'))
    self.__balance = user_balance

    print('pin created successfully')

  def change_pin(self):
    old_pin = input('enter old pin')

    if old_pin == self.pin:
      # let him change the pin
      new_pin = input('enter new pin')
      self.pin = new_pin
      print('pin change successful')
    else:
      print('nai karne de sakta re baba')

  def check_balance(self):
    user_pin = input('enter your pin')
    if user_pin == self.pin:
      print('your balance is ',self.__balance)
    else:
      print('chal nikal yahan se')

  def withdraw(self):
    user_pin = input('enter the pin')
    if user_pin == self.pin:
      # allow to withdraw
      amount = int(input('enter the amount'))
      if amount <= self.__balance:
        self.__balance = self.__balance - amount
        print('withdrawl successful.balance is',self.__balance)
      else:
        print('abe garib')
    else:
      print('sale chor')

# %%
obj=Atm()
# Out:
# 133445648786352

# %%
obj.get_balance()
# Out:
# 0

# %%
obj.set_balance(1000)

# %%
obj.withdraw()
# Out:
# sale chor

# %% [markdown]
# Static variable
#
# static variable class ka variable hota hai
# or instance variable object ka variable hota hai
