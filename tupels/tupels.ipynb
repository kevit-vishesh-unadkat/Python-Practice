# %%
# tuples are immutable in nature 

# typels contain different data type values , ordered 

# tupels allow dulicates

# %%
skills=('pytho','java','c++')
print(skills)
# Out:
# ('pytho', 'java', 'c++')

# %%
num=tuple([1,2,3])
print(num)
# Out:
# (1, 2, 3)

# %%
num[3]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 num[3]
#
# IndexError: tuple index out of range

# %%
num[2]
# Out:
# 3

# %%
num[2]=5  
# tuple is immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 num[2]=5
#
# TypeError: 'tuple' object does not support item assignment

# %%
employee = (
    "E101",
    "Vishesh",
    ["Python", "Java"]
)
print(employee)

# but the mutable object can exist inside the tuple
# Out:
# ('E101', 'Vishesh', ['Python', 'Java'])

# %%
# tuple with type hint

user:tuple[int,str,str]=(
    101,
    "vishesh",
    "Developer"
)

print(user)
# Out:
# (101, 'vishesh', 'Developer')
